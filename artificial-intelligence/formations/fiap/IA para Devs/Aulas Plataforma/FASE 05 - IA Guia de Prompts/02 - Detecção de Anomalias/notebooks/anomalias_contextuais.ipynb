# %% [markdown]
# # Detecção de Anomalias Contextuais
#
# Este notebook demonstra como identificar anomalias contextuais - irregularidades que são incomuns dentro de um determinado contexto, mas podem ser normais em outro.
#
# ## Objetivo
#
# Aprender a detectar anomalias que dependem do contexto para serem identificadas, requerendo conhecimento do domínio.

# %% [markdown]
# ## Importação das Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
