# %%
import nltk

corpus = ["Muito bom este produto", "Muito ruim este produto"]
frequencia = nltk.FreqDist(corpus)
frequencia
# Out:
# FreqDist({'Muito bom este produto': 1, 'Muito ruim este produto': 1})

# %%
from nltk import tokenize

frase = "Muito bom este produto"

token_por_espaço = tokenize.WhitespaceTokenizer()
token_frase = token_por_espaço.tokenize(frase)
token_frase
# Out:
# ['Muito', 'bom', 'este', 'produto']

# %%
from wordcloud import WordCloud
import pandas as pd

avaliacoes = pd.read_csv("b2w.csv")
avaliacoes = avaliacoes.drop([
    "original_index", "review_text_processed", "review_text_tokenized", 
    "rating", "kfold_polarity", "kfold_rating"
], axis=1)
avaliacoes.dropna(inplace=True, axis=0)

todas_avaliacoes = [texto for texto in avaliacoes.review_text]
todas_palavras = ' '.join(todas_avaliacoes)

token_por_espaço = tokenize.WhitespaceTokenizer()
token_dataset = token_por_espaço.tokenize(todas_palavras)
frequencia = nltk.FreqDist(token_dataset)

# %%
dataframe_frequencia = pd.DataFrame({"Palavra": list(frequencia.keys()),
                                    "Frequencia": list(frequencia.values())})

# %%
dataframe_frequencia.head()
# Out:
#                 Palavra  Frequencia
# 0                   Bem         413
# 1                 macio         216
# 2                     e       89308
# 3  felpudo...recomendo.           1
# 4                 Preço         334

# %%
dataframe_frequencia.nlargest(columns = "Frequencia", n = 10)
# Out:
#     Palavra  Frequencia
# 2         e       89308
# 20        o       76053
# 17       de       75791
# 39        a       66640
# 50      que       53574
# 33      não       44253
# 23       do       36776
# 43    muito       36566
# 60        é       36314
# 21  produto       34983

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
ax = sns.barplot(data = dataframe_frequencia.nlargest(columns = "Frequencia", n = 10),
                 x = "Palavra", y = "Frequencia", color = "lightblue")
ax.set(ylabel = "Contagem")
plt.show()

# %%
def grafico(dados, coluna_texto, quantidade):
  todas_palavras = ' '.join([texto for texto in dados[coluna_texto]])
  token_frase = token_por_espaço.tokenize(todas_palavras)
  frequencia = nltk.FreqDist(token_frase)
  dataframe_frequencia = pd.DataFrame({"Palavra": list(frequencia.keys()),
                                    "Frequencia": list(frequencia.values())})
  dataframe_frequencia = dataframe_frequencia.nlargest(columns = "Frequencia",
                                                       n = quantidade)
 
  plt.figure(figsize=(12,8))
  ax = sns.barplot(data = dataframe_frequencia,
                  x = "Palavra", y = "Frequencia", color = "lightblue")
  ax.set(ylabel = "Contagem")
  plt.show()

# %%
palavras_irrelevantes = nltk.corpus.stopwords.words("portuguese")
palavras_irrelevantes
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
frase_processada = list()
for avaliacao in avaliacoes.review_text:
  nova_frase = list()
  palavras_texto = token_por_espaço.tokenize(avaliacao)
  for palavra in palavras_texto:
    if palavra not in palavras_irrelevantes:
      nova_frase.append(palavra)
  frase_processada.append(' '.join(nova_frase))

avaliacoes["texto_sem_stopwords"] = frase_processada

# %%
avaliacoes.head()
# Out:
#                                          review_text  polarity  \
# 0  Bem macio e felpudo...recomendo.  Preço imbatí...       1.0
# 1  Produto excepcional!  recomendo!!! inovador e ...       1.0
# 2  recebi o produto antes do prazo mas veio com d...       0.0
# 3  Bom custo beneficio. Adequado para pessoas que...       1.0
# 5  ótmo produto atendeu as expectativas, a entreg...       1.0
#
#                                  texto_sem_stopwords
# 0  Bem macio felpudo...recomendo. Preço imbatível...
# 1  Produto excepcional! recomendo!!! inovador gos...
# 2  recebi produto antes prazo veio defeito trava ...
# 3  Bom custo beneficio. Adequado pessoas fazem us...
# 5  ótmo produto atendeu expectativas, entrega oco...

# %%
grafico(avaliacoes, "texto_sem_stopwords", 20)

# %%
from nltk import tokenize 
frase = "Muito bom este produto"
token_pontuacao = tokenize.WordPunctTokenizer()
token_frase = token_pontuacao.tokenize(frase)
token_frase
# Out:
# ['Muito', 'bom', 'este', 'produto']

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
pontuacao = list()
for ponto in punctuation:
  pontuacao.append(ponto)
pontuacao
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
pontuacao_stopwords = pontuacao + palavras_irrelevantes


frase_processada = list()
for avaliacao in avaliacoes.texto_sem_stopwords:
  nova_frase = list()
  palavras_texto = token_pontuacao.tokenize(avaliacao)
  for palavra in palavras_texto:
    if palavra not in pontuacao_stopwords:
      nova_frase.append(palavra)
  frase_processada.append(' '.join(nova_frase))

avaliacoes["texto_sem_stopwords_e_pontuacao"] = frase_processada

# %%
grafico(avaliacoes, "texto_sem_stopwords_e_pontuacao", 20)

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /home/lucas-biason/Estudos/IA-Studies/venv/lib/python3.13/site-packages (1.4.0)

# %%
import unidecode

acentos = "Ótimo péssimo não tão é"
unidecode.unidecode(acentos)
# Out:
# 'Otimo pessimo nao tao e'

# %%
sem_acentos = [unidecode.unidecode(texto) for texto in avaliacoes.texto_sem_stopwords_e_pontuacao]
sem_acentos
# Out:
# ['Bem macio felpudo ... recomendo Preco imbativel entrega rapida Compraria outro precisar',
#  'Produto excepcional recomendo !!! inovador gostoso ler !!',
#  'recebi produto antes prazo veio defeito trava usar agora Americanas resolveu preciso deste produto',
#  'Bom custo beneficio Adequado pessoas fazem uso casual aparelho A maquina fotografica excelente A tela fornece imagens otimas Os recursos aparelho faceis manejar',
#  'otmo produto atendeu expectativas entrega ocorreu antes previsto bom',
#  'GOSTEI MUITO DO PRODUTO TEM OTIMA QUALIDADE E FACILITA MUITO A APLICACAO DO GEL',
#  'Adorei entrega prazo produto conforme esperava recomendadissimo',
#  'Ja segundo processador deste modelo compro primeiro mae elogios E forte facilita bastante processos',
#  'Nao recebi !!! endereco entrega rua augusto hog 186 casa 02 jardim presidente dutra guarulhos sp cep 07172200 favor enviar !!!',
#  'Nao compra produto pois veio botoes travados tentar ligar ligou Pessima qualidade',
#  'Adorei smartphone excelente acabamento veloz intuitivo',
#  'Tive azar pois produto ligou Tive entregar fornecedor',
#  'Uma enganacao Esperei quase mes cancelaram pedido E produto continua disponivel Nem entraram contato Palhacada !!! carrodemola',
#  'O produto chegou antes prazo estimado Otimo produto Recomendo todos vendedor',
#  'produto excelente Atingiu expectativas Recomendo produto',
#  'Lindo relogio entrega super rapida Estou satisfeita compra',
#  'Atendeu expectativas funcionou perfeitamente repetidor sinal',
#  'Recomendo compra cartuchos HP outros produtos site americanas',
#  'show !...........................................................................................................................................................................................................................................................................................',
#  'Um Produto bom simples recomendo telivisao todos',
#  'Estou gostando torradeira Gourmet Oster bonita eficiente',
#  'Estou satisfeito servico prestado americanas',
#  'Aparelho bom Otima imagem fotos maravilhosas',
#  'Cancelei 10 minutos efetuei compra mandaram assim',
#  'Muito bom valeu pena compra Muito bonito Gostei',
#  'Capa flexivel macia deixa celular firme mao',
#  'Na estacao som tudo correto estalar autuofalante sai som',
#  'Adorei celular Produto excelente Atende necessidades',
#  'Produto emborrachado otimo crianca pequena Chegou super rapido neta 1 5 anos adorou',
#  'Balcao bonito Entrega prazo Material fragil Veio faltando parafusos fixacao tampo assim faltou protecao cor preta atras tampo aparece imagem Montagem facil manual instrucoes poderia completo Nao recomendo falta parafusos protecao',
#  'Para mim util Tem tudo preciso Facil encontrar configuracoes aplicativos baixam rapidos Camera otima muitos filtros selfie facil manuseiar',
#  'Adquirir pipoqueira eletrica satisfeito resultado',
#  'Otimo produto pecas qualidade bonitas bem acabadas Recomendo',
#  'Otimo !!! adoro produto comprei outras vezes gostei agora comprei dnovo super recomendo',
#  'Gostei deste produto principalmente designe',
#  'Eu comprei produto entretanto entregue produto diferente entregue produto aceita somente chip modelo k33b37 alem disso veio faltando fone Estou comunicacao parceira Eletrobest enviaram codigo postal enviar fazer troca O produto veio apesar errado produto bom design bonito leve muitas funcionalidades entretanto mencionado empresa parceira cometeu dois erros considero erros primarios graves mandar produto errado faltando fone',
#  'Estou decepcionada servico oferecido americanas Venceu prazo entrega recebi produto',
#  'Bom dia posso fazer avaliacao pois produto incompativel rodar XBOX 360 havia notado rodape capa ter XBOX GOLD tentei realizar troca loja fisica Presidente Prudente possivel',
#  'Comprei smart tv samsung 49 amei produto Eu recomendo sim tanto produto loja Nao arrependo ter adquirido ... Corra Americanas proxima garanta Tv samsung 49 otima parceira assistir copa Penae nisso',
#  'No primeiro uso encheu bolinhas mangas atrito moletom cria varias bolinhas',
#  'Chegou super rapido bem antes prazo entrega Sao lindas super resistente tampa bem flequixivel',
#  'Produto boa qualidade loja MUNDO MAC STORE surpreendeu bom atendimento prazo entrega RECOMENDO',
#  'Gostei produto americanas rapida entrega curtindo novo aparelho facil navegar rapido devido processador Muito satisfeita',
#  'Acho site deveria deixar claro original',
#  'ainda recebi produto ainda aguardando recebimento',
#  'produto excelente qualidade jogo intenso historia boa entrega prazo',
#  'Apenas faltou bolso frente suportes tela laterais serem pouco maiores Produto excelente',
#  'Poxa vida desse jeito nao ne Americanas comprei jogo dia 20 03 nada produto lancado dia 20 04 comprei repelente dia 18 04 chegou hoje assim cai conceito ne Americanas relacao site sempre boa pisou bola demais comprei pre venda confiando produto pudesse chegar maximo dia 23 04 nada pensar compro outro jogo pre venda aqui desculpe fiquei puto tanto pre venda lancado preco alteracao entao pensei menos vou receber jogo maximo uns tres dias aconteceu pra piorar comprei outro produto chegou 6 dias apos compra brincadeira ne Americanas Brincadeira',
#  'conheco equipamento entao sei qualidade produto',
#  'Comprei faz ano dois meses assistencia 2 vezes defeito problema solucionou Smartphone horrivel',
#  'Gostei perfume maravilhoso O Frasco poderia maior',
#  'Produto maravilhoso ficou facil limpar',
#  'Nao comprem produto comprei dar presente chegou casa outro jogo minecraft dlcs Tentei contato LIXO AMERICANAS responde MENSAGEM AUTOMATICA dao retorno Nao recomendo comprar americanas',
#  'Indico aparelho Ar Condicionado Janela 10 000 Btu s',
#  'PRODUTO BOM RECOMENTO E BONITO BARATO E SILENCIOSO',
#  'otimo material estudar esclarecer sobre comportamento infantil',
#  'Como descobri produto antes Pratico funcional Gostei vou usar casa pousada piso branco',
#  'atendeu todas expectativas equipamento bom facil manusear',
#  'Excelente kit composto portao extensores Atendeu totalmente necessidade Apesar conta mercado confio marca Tenho conhecimento qualidade principalmente durabilidade produto Investimento longo prazo Melhor custo beneficio todos',
#  'Um produto bom servico entrega rapido faz toda diferenca Espero continue sempre assim atendimento clientes',
#  'Muito bom msm recomendo A bateria otima assim cameras frontal traseira Top',
#  'Toalhas grandes qualidade Buddemeyer Ja outras toalhas dessa marca conta Americanas decidi comprar Td bom Recomendo',
#  'Comprei dois moto G5s Muito bom chegou tudo certinho menos tempo Super indico site americanas compra certa',
#  'Ainda nao recebi produto entao nao avaliar',
#  'comprei instrumento fiquei pe atras assim chegou produto fique bastante surpreso bem embalado esteticamente bonito sonoridade bem firme instrumento bem afinado Super recomendo todos Obrigado',
#  'comprei achando aparelho original infelizmente replica chateada Americana esperava receber replica rede loja tao grande',
#  'Ainda estudando livro prefiro fazer comentarios Porem primeir superficial analise acho livro bem estruturado',
#  'Fez merecer nota produto qualidade entrega obrigado',
#  'Muito rapido excelente tela otimo preco x beneficio',
#  'Nao entregaram produto ainda colocaram sistema entregue dia 12 12 2017 Tento entrar contato respondem',
#  'Extremamente insatisfeita atendimento Estou aguardando estorno pagamento cartao',
#  'Comprei produto voltagem veio outra Ate agora problema solucionado',
#  'produto chegou roboram mao grande nai fizeram entrega cumpriram prometido aconselho ninguem',
#  'Bom posso dizer prazo entrega beleza produto presente casamento',
#  'HA MAIS DE 20 ANOS USO BARBEADOR ELETRICO DA PHILIPS ESTE MODELO SUPEROU AS MINHAS EXPECTATIVAS COM RELACAO AO USO EXCELENTE E FACIL DE USAR LIMPEZA FACILITADA APOS O USO ADOREI MESMO PARABENS A PHILIPS',
#  'Quando telefone chegou aqui cidade ja quase 200 00 barato',
#  'Belo acabamento impressao impecavel Indico gosta colecionar quadrinhos quer presentar alguem gosta 9a arte Recomendadissimo',
#  'qualquer arrependimento produto fantastico pratico silencioso lindo',
#  'Produto chegou amassado Pedi devolucao site nunca retornaram procedimento Acabei pagando caro panela defeituosa Nao compraria polishop novamente',
#  'suga bem pratico leve Unico problema poder usar aspirador embaixo cama baixa armarios',
#  'Acabo receber alerta preco R 577 imediatamente cliquei comprar E JA APARECE SEM ESTOQUE !!! Propaganda enganosa pouco',
#  'Livros excelentes atenderam expectativas',
#  'resolveu problema wi fi alcancar demais comodos casa',
#  'quanto abri produto dei conta vezes comprar Internet pode deixar frustados !!!',
#  'gostaria saber parte recipiente aonde colocamos oleo conseguimos retirar lavar',
#  'Foi otimo custo x beneficio Tem boa iluminacao',
#  'Tudo ocorreu perfeito Desde momento pagamento produto',
#  'Testei varios removedores cravos ja desde mascara preta ate extrator parece pinca melhor sombra duvidas siper recomendo obrigada',
#  'O acabamento otimo funciona bem sobrecarregar instalacao eletrica A entrega exatamente data prevista',
#  'Nao gostei produto comprei porque descricao site induz objeto qualidade profissional etc todavia deixou desejar feito aluminio pote suco feito plastico grosseiro Nao recomendo Fui descricao toque arrojado espremedor',
#  'Gostei cafeteira preco bom facil usar So recebi capsulas combo hoje',
#  'Falta enviar pote ainda entregue obrigado',
#  'Produto eficiente pratico adequado limpezas baixo camas armarios etc ...',
#  'Recomendo pois encaixa perfeitamente modelo camioneta',
#  'Eu a oposicao troca devolucao produto cunhado quis fazer procedimento tudo bem espero outros dois produtos venha defeito',
#  'chegou antes prazo esquenta dedos queimados kkkk',
#  'O atendimento bastante satisfatorio O Blu ray estado satisfatorio',
#  'sempre vontade comprar produto bem imaginava',
#  'Excelente produto fato ter luz forno bivolt diferencial bom',
#  'O produto entregue excelente entregue danificacoes pouco atraso Muito bom',
#  'Excelente qualidade tamanho ideal Preco promocional excelente compativel tamanho',
#  'Fiz compra desse produto dia 21 02 2018 hoje 26 03 2018 recebi sendo assim posso avaliar produto bom ruim quanto fornecedor NAO RECOMENDO',
#  'otimo lindo aconchegante elegante tamanho maravilhoso',
#  'Dentro prazo produto impecavel Apenas controle mau funcionamento',
#  'gostei ventila produto otima qualidade nao barulhento super recomendo',
#  'O produto si legal porem falha trava acaba prejudicando pouco',
#  'Exatamente esperando entrega prazo',
#  'Fiz compra ainda recebi pedido Aguardo hoje entrega Ninguem fez contato ainda avisar da entrega',
#  'Muito boa bem reforcada atendeu expectativas ate agora',
#  'Nao recebi produto agora vou comprar outro lugar colocar americana justica pago primeira parcela',
#  'Meu jogo chegou antes data prevista veio tudo certinho ... Gracas Deus uns dias antes paralizacao kkk',
#  'As lanternas boas dei sorte pois diferencas polimento',
#  'produto bom recomendo todos recebi prazo previsto tudo ok certinho recomendo',
#  'Ja usava caneta macia falha vai fim tinta',
#  'O aparelho bonito traz boas funcoes !! Fiquei chateado audio fica escala regular pra ruim infelizmente ... Acredito aparelho poderia compacto tamanho',
#  'Um aparelho baixo custo alta precisao onde acho todos deveria ter casas',
#  'Ainda recebi produto favor providencie entrega hiper atrasado prometido dia 27 marco 6 Abril',
#  'Produto boa qualidade chegou antes data prevista',
#  'Nao esperava aguardo contato troca',
#  'Basa grossa usar tampo vidro transparente fica feio pq destaca bastante base grossa demais achei produto qualidade regular',
#  'otimo produto bonito confortavel leve gostei',
#  'Chegou bom estado defeitos Bem lacrado E contar chegou bem antes dia previsto Amei Excelente Recomendo',
#  'Livro excelente A entrega feita rapida Super recomendo',
#  'Excelente compra ... chegou antes prazo bom comprar',
#  'Nao falar entrega chegou antes previsto produto bem embalado perfeitas condicoes Tudo certo A B2B Games parabens competencia zelo clientes',
#  'Produto veio quebrado Produto veio imundo impressao usado LojaTudo nunca Nao respeito menos consideracao clientes Na primeira compra feita enviam produto quebrado totalmente sujo Loja tudo nota 0 Nao comprem loja tudo Nao compre loja tudo loja tudo Loja tudo boa Loja tudo entrega produtos quebrados Loja tudo confiavel',
#  'Amei produto otimo cumpre mto bem proposito super recomendo Chegou antes data prevista !!!',
#  'Lindo .. Confortavel .. Fashion .. otima qualidade .. Recomendo',
#  'O texto titulo fala Gigabit aparelho 10 100',
#  'Otimo produto entrega rapida recomendo cumpre q promete',
#  'AVALIACAO EXCELENTE PARABENS PELA QUALIDADE E ENTREGA EFICIENTE SUPER CONFORTAVEL E BONITAS',
#  'Produto excelente qualidade impressao nitida nada perde original comprei 2 recomendo',
#  'Comprei site Americanas produto apresentou defeitos Entrei contato devolvi Americanas fez reembolso nenhum estresse Porem comprei produto loja fisica perfeito amei troco nada Parabens Americanas manter sempre contato durante devolucao As vezes defeito lote Enfim .. produto perfeito',
#  'O produto bem acabada imagem n oque esperava tudo bem vo 8',
#  'Produto boa qualidade atendeu expectativas',
#  'O armario si razoavel Lado negativo veio faltando peca Americanas quer resposta deu 3 vezes tentei contato !! Nao recomendo ninguem Pos compra pessimo Estao ai clientes',
#  'Roteador otimo diversos recursos Chegou caixa perfeito estado entrega super rapida bem antes prazo final',
#  'Satisfeita compra exatamente descrito material boa qualidade perfeitamente embalado Equipe entrega eficiente entraram contato algumas vezes ...) simpaticos Parabens master box design Nao entregue prazo previsto momento compra ...',
#  'Comprei produto paguei frete altissimo apos produto chegar transportadora ficou quase 30 dias parado movimentacao menos produto chegou endereco entrega rastreio atualizado',
#  'Minha casa roupas viviam gato todos lados gata vomitava bola vez semana produto simplesmente eliminou Comprei porque gata idosa parou lamber ficando rastafari resolver problema pesquisei sobre escovas gatos acabei lendo inumeras boas avaliacoes produto Ele problema avisado nenhum lugar quebra animal Nao produto uso diario uso semanal quinzenal mensal ... Veja bem limitacao cumpre bem promete diminuir drasticamente quantidade ambiente sistema digestivo felino caso impedir mudanca religiao gato religiao rastafari rsrsrsrs Nada contra rastas viu pessoal ?! rsrsrs So gostoso passar mao desembaracado',
#  'RECOMENDO MUITO BOA A TV SO DEMOROU MUITO PARA ENTREGAR',
#  'Alem caro produto pessima qualidade serve brincar tampouco usar rua exceto magro musculoso logo sublimado parte interna todo branco camisas ganhei jogos selecao dadas Bradesco apesar serem descartaveis qualidade nova camisa R 30 camisa preco maximo agora R 129 Estao brincando cara ne',
#  'Alem produto vir nota fiscal faz desconfiar originalidade ), mal embalado veio defeito pois pecisa ficar mexendo fio pra ajustar som',
#  'Entrega transportadora bem Rapida Produto bom excelente configuracoes atualizacoes deixam lento selecione permitir atualizacao',
#  'Recomendo devolvam dinheiro mande carta pedindo desculpa LIXO comprei Sacanagem enganacao Nao sei americanas deixa oferecer produto LIXO ai ... LIXO LIXO LIXO Isso parece meia velha ... alguem ja falou ai embaixo .. LIXO',
#  'Tive pedido cancelado site apos ter pago Um desrespeito',
#  'Estou satisfeito monitor Estava busca tempo dai pintou boa promocao aqui usando Otima qualidade imagem aparencia tudo bom Tenho certeza fiz otima compra acredito fara Recomendadissimo !!!',
#  'Acabei abrir segredo digital funciona So abre fecha chave Teclado inoperante Estou decepcionado Acabei arrumando problema Espero consiga trocar Ja descobri pesquisando pos venda ruim E frustrante Primeira vez chateio lojas americanas Ja comprado outras vezes Vou continuar acreditando L A Mas recomendo produto Lamentavel Queria aqui elogiando Mas posso',
#  'Adorei Realmente cumpre promete O cortador respingos funciona apenas acho cafe fica quente poderia melhorar nisso',
#  'Cada compro vem firmware programa diferente compromete qualidade produto pois alguns travam todos superaquecem impressao vai queimar qualquer momento O marca NOVA DIGITAL menos recomendo pois trava canais boa antena apresenta problemas configuracao O VMADE Made altera ordem canais conta propria Pessimos softwares nesse modelo equipamento Sou tecnico eletronica',
#  'Vem explicar forma rapida simples processo letramento crianca desenvolve',
#  'Otimo produto Tive contratempo hora instalacao Americanas junto Samsung solucionou bem Maravilhoso',
#  'Otimo custo X beneficio Recomendo Os copos otima qualidade',
#  'vc carro antigo bluetooth entrada auxiliar vc precisa comprar destes',
#  'Celular otimo processador rapido boa capacidade memoria',
#  'Produto otima qualidade resistente confortavel Entrega rapida',
#  'Apesar ter quebrado cabeca montar cadeira otima visualmente confortavel',
#  'Por hora utilizado apenas fazer curso online navegar internet Para proposito aprovadissimo Mas comprei editar videos Mais ainda utilizei portanto avaliar',
#  'Bom suporte bom acabamento resistente Cumpre bem funcao recomendoa compra',
#  'Excelente aparelho Recomendo As Americanas parabens Entregou bem antes prazo',
#  'Gostei produto mulher adorou Tem prateleira interna pra bastante coisa obrigado',
#  'Apesar ter pouco tempo recebi produto observei camera excelente tamanho tela bom encaixe Quanto entrega produto chegou bem antes prazo estimado',
#  'Otimo celular bom desempenho intermediario Tela bonita processador legal flash frontal otima qualidade',
#  'O jogo bom bem completo aue versao anterior',
#  'Fiz boa compra Produto bom So pequeno problema Nao sei aconteceu primeiro chegou pois pareceu usado Chegou marcas dedo arranhoes riscos peca frente mede nivel agua quebrada Fiz troca imediata antes semana deram outro ... tirando excelente produto ... recomendo comprem ...',
#  'O produto veio certinho facil encher Porem pouca durabilidade',
#  'O aparelho veio defeito vcs dizem q passou tempo reclamar E eh entrar contato fornecedor Que lembre comprei americanas Entrei site americanas confiar Nao compro conheco Ou adiantou nada Pessima experiencia Agora produto pifado funcionar caro vou ter correr atras pra resolver vcs eximem problema Muito obrigado pessimo atendimento Evitarei futuras compras vcs',
#  'Tudo perfeito entregue prazo perfeitas condicoes ,,,,,,',
#  'adorei tudo chegou super rapido antes prazo super recomendo obrigado',
#  'Pelo preco produto atente promete satisfeito compra',
#  'melhores aparelho ja comprei satisfeito produto loja americanas toda equipe parabens continue assim obrigado',
#  'Muito bom ... gostei Tudo otimo Nao Sei pq preciso escrever tanto avaliar produto',
#  'NAO RECOMENDO TAPETE DE PESSIMA QUALIDADE BEM DIFERENTE DA FOTO SEM SE COMPARA',
#  'As dimensoes desta caixa verramentas anuncio 16 cm x 16 cm x 11 cm Nao cabe nada pequena',
#  'comprei internete chegou tempo certo problemas adoreiiiii',
#  'FOI ENTREGUE NO PRAZO E ATENDEU PLENAMENTE AS MINHAS EXPECTATIVAS RECOMENDO',
#  'Gostei produto achei ruim solta tinta vc faz alguns alimentos fica grudado alimento Fora 10',
#  'Me ajudem dinheiro aluguel Minha conta 0000 4444 4',
#  'O livro bom recomendo chegou tempo certo',
#  'Um otimo custo beneficio Excelente qualidade Vale pena !!',
#  'Adorei produto gostei comprar lojas americanas recebi antes prazo marcado obgda .... josa',
#  'Lindo smartphone entrega rapida antes prazo Recomendo produto compra loja',
#  'Gostei produto chegou prazo recomendo Unico ponto negativo manual portugues apenas ingles espanhol',
#  'O encosto veio varios arames amassados falha pintura banqueta acabamento pessimo muitas rebarbas inclusive machucando arranhou braco passar Poderia ter caprichado entregar produto ninguem olha produto antes embalar',
#  'Porque recebi nada site confirmaram recebi ai fico',
#  'Como pode mandarem mail pra avaliar produto recebeu Porque mandam mail informacoes sobre porque ter sido entregue util Uma falta consideracao consumidor passarmos mes compra O prazo pra entrega venceu desde entao mandei inumeros mail nenhum respondido informacoes sobre produto Ate agora esperando nada',
#  'Recomendo otimo maquina !!......... .................',
#  'Bebedouro perfeito gela bem bonito atendeu plenamente Igreja Chegou antes prazo combinado Recomendo',
#  'O produto bom Realmente retira cheiro mofo armario',
#  'Muito boa sempre bosch Quer algo duravel eficiente bosch',
#  'Vendedor bom entrega rapida antes prazo',
#  'Gostei produto recomendo Entrega rapida produto qualidade',
#  'Achei recepcao ruim canais Tenho estilo outra marca q funciona perfeitamente',
#  'Nao gruda todos menos qdo vai limpar pra passar novo limpa poucp',
#  'Material qualidade ... superou expectativas',
#  'Muito confortavel produto bom Produto realmente deixa fresco adorei ...',
#  'No anuncio duralex produto marinex .. qualidade inferior .. fiz devolucao produto faz mes ainda reembolsado !! Muito insatisfeito empresa',
#  'Como farei aniversario dia 3 fevereiro pedi panelas pro marido AMEI',
#  'Confesso q medo produto superou expectativas gostei E entrega tb chegou antes previsto Parabens !!!',
#  'Nao oque falar Game reclamacao demora entrega',
#  'Nao recomendo pois comprei pq achei baratinho precisando nunca recebi Ja quase 3 meses deram satisfacao todos dias tento retorno nada',
#  'Produto otima qualidade preco Destaco qualidade tela sinal otima',
#  'Este produto muitos dizem progressiva porcentagem formol pouco acima So muitas reclamando arde couro cabeludo amacia cabelo Bom trabalho sempre marca sempre comprei aqui site lojas AMERICANAS PROGRESSIVA qualquer tipo produto quimico reacao fortes chegam alisar cabelo deve encostar couro cabeludo processo progressiva trabalhoso pessoas saibam fazer Nao adianta querer comprar produtos caros conseguir segue trabalhar barato Bom sempre trabalhei marca outra clientes pre voltaram idicam',
#  'A propagando levar crer comprando produto alta pressao Pois alem potencia tecnica 1750 Lbs nome Produto leva grafia 2200 confunde completamente consumidor leigo Comparei 1750lbs Lavadora Wap 1750Lbs concorrente TEKNE fiquei surpreso diferenca Por recomendo produto',
#  'Entrega super rapida produto atendendo todas minhs expectativas',
#  'Otimo custo beneficio entrega rapida Parabens',
#  'Apesar prazo vencido produto entregue conforme descrito Estou aguardando entrega rapido possivel',
#  'Para perfil jogador games profissional multimidia notebook otima aposta Eu usando duas coisas resutados sido interessantes Ele roda temperatura agradavel silencioso trabalha rapido No geral configuracao forte entao vou citar dois pontos fracos 1 HD hibrido SSD SATA gera boa experiencia particao 128 GB Windows mexer 1 TB SATA decepcionante tao lento Voce pensar bem estruturar arquivos 2 O monitor grande coisa Faz servico qualidade ideal cores pouco vibrantes brilho fraco bem ausente Pra quer cor bonita vai ter plugar TV monitor externo Uma nota importante comprar primeira metade 2018 Todos notebooks padrao gamer problema compatibilidade placa Intel GeForce ocasionando pulos estranhos durante uso Nao Lenovo todas marcas Para corrigir enquanto empresas acertam precisa baixar programa gratuito pequeno chamado TrayPowerD3 corrige Ai note vai rodar liso',
#  'O produto veio defeito telefone Sac Americanas nunca funciona sempre manda ligar porque todos atendentes sempre ocupados ), entrei reclame aqui ... baita transtorno conseguir fazer troca Nesse meio tempo mudei endereco estado !) politica troca aceita mude endereco entrega Me articulei pais crianca havia presenteado zelador predio nova moradora fim chegar boneca funcionar menos 10 min pifar Chega video pai celular mensagem Descartavel travou motor acompanhada video comicamente deprimente boneca girando base musica toda distorcida ... gastem suado dinheirinho porcaria',
#  'Adorei mesa bistro ... material bom Super recomendo Entrga antes combinado',
#  'A entrega sempre rapida O perfume bom suave marcante cumpre bem promete preco esperado',
#  'A piscina linda filha adorou Produto excelente',
#  'Solicitei devolucao momento obtive retorno',
#  'produto bom porem passar tempo costura vai apodrecendo requer nova costura velcros',
#  'comprei tv dia 24 01 ate hoje 27 02 nunca entregue status transportadora diz tv retida sob fiscalizacao diabos .. sempre compro americana sinceramente dessa vez decepcionada dar proxima vez vou procurar outros sites',
#  'Livro bom entregaram antes prazo otimo estado',
#  'recebi produto errado faltando 1 unidade pois pedi 2 redmi note 5 5 5 mandaram redmi 5a 5 0 polegadas ja mandei volta ja chegou ai dia 01 03 hoje ja 08 03 nao mandaram nenhum email rastreio dizendo produtos enviados desta vez corretamente ja enviei varios emails ja saco cheio pecimo atendimento encontro pois inves entrarem contato rapido resolver cara atendeu dizendo sabia devolvido pedido veio errado simplismente disse retornaria contato 3 dias ta brincadeira ne pra devolver chegar ai apenas 3 dias enviarem certos pra mim ja faz 7 dias espero nada .... disse emails vou resolver outra forma pois conversando vcs nao ainda ditando prazo pra falar consumidor sao maior bem melhorem atendimento ...',
#  'Chegou antes previsao site problemas compra entrega',
#  'O produto bom porem deu defeito 20 dias uso',
#  'Produto acordo anuncio veio bem embalado excelente',
#  'Nao original .. Nao resultados ... So shake bom',
#  'Cancelaram pedido porque produto ainda pedem avaliacao',
#  'Alem linda boa qualidade recomendo !!!',
#  'Otimo Funciona bem Capta som perfeitamente De acordo configuracao ruido capta Excelente investir',
#  'Produto correto entrega antes data prevista entrega',
#  'Celular eccelente leve boa performance otima camera',
#  'Ridiculo site grande desse enviar produto errado agora vai ir atraz pra trocar Eu bb recen nascido RIDICULO AMERICANAS',
#  'entrega excelente produto otimo perfeito recomendo produto pratico utilizar',
#  'Se existisse 0 estrelas daria Nao produto loja enviou produto pessimo marca totalmente divergente Faz semanas pedindo enviem codigo postar produto receber estorno ainda espera Totalmente insatisfeita',
#  'Nao branca branca Igual Led bem brilhante normal',
#  'Excelente custo beneficio Produto bom preco bom chegou rapido Tudo acordo esperado Excelente criancas',
#  'Comprei produto paguei vista atraves boleto Agora alegam estoque ninguem da posicao Nao recomendo jeito nenhum pois hora fechar pedido nenhum aviso produto falta',
#  'Muito bom armario marido montou rapidinho ficou lindo cozinha nova',
#  'O revolver aplicador vaza conexao possivel utilizar mangueira',
#  'apresentou defeito 11 dias uso 3 riscos horizontais imagem tv saiu parede vou enviar p assistencia tecnica amanha passou prazo 5 dias corridos entrega assistencia tecnica q resolve',
#  'Otimo aparelho interessar pode comprar',
#  'Um produto otimo bem escrito Super recomendo',
#  'oi boa noite quero saber vao devolver dinheiro mandei produto ficou faltando pistola quero saber vao restituir pq ainda estao cobrando cartao credito',
#  'Nao recomendo pois funciona Wi Fi maioria vezes conecta baixar app dificil encontrar pois manual chines russo ajuda nada Por recomendo',
#  'O produto bom Mas pano fica sempre agua absorcao agua direito torcer Mas produto pratico dia dia',
#  'Melhor jogo genero ultimos tempos Graficos excelentes jogabilidade pratica',
#  'Bonita facil carregar porem mantem alimentos quentes',
#  'Infelizmente problemas pois consegui receber produto dentro prazo 13 dias atraso',
#  'ja reclamei resposta agora quero cancelar quero dinheiro juros correcao NAO RECEBI O PRODUTO ATE AGROA',
#  'Gostei celular pq pessoa problema visao numeros tamanho bom Muito bem recomendado idosos Obrigada',
#  'Gostei compra grill tamanho bom pequeno grande esquenta rapido entrega antes prazo',
#  'Gostei produto recomendo compra entrega combinado',
#  'O produto bom preste atencao quantidade anuncio pois 36 gramas bem pouco',
#  'E primeiro Motorola adorando Podem comprar vale pena',
#  'Bonito produto ... pouca utilidade ... anatomia fica dificil usar ...',
#  'Ja deu defeito avalio pessimo Nao recomendo amigos',
#  'Comprei pra mae adorou produto otima qualidade entrega super rapida',
#  'Gostei ter comprado produto site',
#  'descricao caixa produto diz 28 cm porem',
#  'Unica silicone hidrogel colorida Vale cara centavo Melhor conforto',
#  'Cadeira veio defeito hidraulico dois rasgos torta amassado apoio pes Ate agora consegui solucionar problema Ja conversei atendente comunicado iriam resolver problema Porem unica maneira resolver enviar nova trocar comigo Mas agora nada',
#  'O pen drive recebi diferente comprei Comprei produto veio outro',
#  'O produto adquirido corresponde ofertado loja',
#  'Um produto super pratico facilita demais dia dia mulher',
#  'Ainda recebi produto Nao avaliar produto ainda nao recebi',
#  'Produto superou expectativas otima qualidade bonito excelente custo beneficio Recomendo',
#  'Produto chegou preencheu expectativas Recomendo',
#  'ESSE PRODUTO NAO CHEGOU EM MINHA RESIDENCIA !!!!!! Descontaram valor cartao produto chegou residencia Fui noite correios endereco final sendo SAO PAULO porem endereco RIO DE JANEIRO Quero dinheiro volta produto !!',
#  'arrependi ter comprado acabamento mal feito garfos corta boca compre',
#  'Nao compremm .. apenas 2 meses camera ja deu pau .. foca outras coisas ..',
#  'Entrega rapida chegou tudo certo lacrado O perfume bom ja conhecia',
#  'Excelente produto !!! CONTEMPLA AO QUE SE PROPOE !!!',
#  'Tamanho ideal imagem otima Exatamente buscava',
#  'Eu conheco qualidade produtos Santista fiquei contente satisfeita compra',
#  'Eu recebi produto sujo desbotado ... Nao recomendo ...',
#  'Eu amei penteadeira Fiquei meses procurando algo tipo so achava precos absurdos Essa super recomendo',
#  'Superou expectativas Muiiiiito bom E tao barulhento',
#  'Produto bom rendimento excelente esperando',
#  'comprei produto vcs disseram q entregariam dia 23 ate hj recebi vcs entram contato informar sobre entrega devolucao dinheiro frustada pos sempre cliente lojas americanas pos vcs mostram interesse resolver problema entro contato respondida produto sei bom chaga sei lojas americanas sendo boa empresa fazer compras !!!!!!!!!!!!',
#  'Normalmente dar 5 estrelas todas avaliacoes rigoroso pois pesquiso antes comprar algo No entanto aqui comprei exatamente 27 11 17 supostamente presente natal 02 01 18 ainda chegou A americanas entrou contato querer reembolsar valor quero reembolso quero produto comprei Espero resolver quanto antes Fiquei bastante triste servico A atendente alegou produto havia estoque pergunto porque vender algo Sem comentarios',
#  'A Americanas salvaram tio produto tendo problemas motor marca passo familia substituiu 572 720 hp velho descarga alterada toda vez come feijao solta pum sai jornal noticia bala perdida',
#  'O produto mto vagabundo material nau bom gavetas vale nada7 odiei recomendo ninguem',
#  'Bom pena pagar valor vir cabo carregar vou ter gastar dinheiro frete pra poder comprar cabo poderiam pensar nisso prox vez facilitar vida cliente',
#  'Dentro padroes informados anuncio entrega super rapida',
#  'Excelencia entrega bom atendimento americanas',
#  'Estou apaixonada sabor super docinho maravilhoso Vale super pena comprar',
#  'Fiz compra mes marco agora nada entregar produto .... dao satisfacao ... liguei varias vezes central confirmam data entrega entrega nunca acontece Estou totalmente decepcionada pior coisa fiz comprar nessa porcaria desse site vale nada .... Se condicoes atender cliente melhor colocar ar ... Decepcao total ..... recomendo !!!',
#  'A linha expert revigora nutre trata cabelos normais secos deixa perfume incrivel Usado apos shampoo linha entrega tratamento salao Age defy favorito',
#  'Quero saber vao entregar produto pq entregue',
#  'gavetona coloquei apetrechos cozinha coube bastante coisa marido montou achei facil rs',
#  'Celular boa performance entrega designer bonita alem tecnologia atual onde integra otima camera',
#  'Mto bonita mtas funcoes so achei controle simples',
#  'Atendeu expectativas recomendo facil instalacao bonito esteticamente',
#  'A imagem anuncio traz case rigido preto entregue capa emborrachada cor laranja HD NAO entregue ). Ao informar capa entregue recebi ligacao informando enganado pois capa custava R 2 000 00 Realmente enganado anuncio enganador atendimento mal carater Nem quer existe anuncio suposta capa 2 000 ". O valor maior HD certamente acham idiotas tentando fazer cliente pensar engano informando valor absurdo produto oferecido separadamente Na propria imagem disponibilizada nesta pagina avaliacao case acompanhado capa cor laranja Anuncio fraudulento atendimento pessimo Sou cliente anos jamais problemas compra Este parceiro prejudica marca Americanas Jamais pensei anos cliente receber atendimento tao ruim mentiroso',
#  'Eu querendo comprar novo microondas fiz muitas pesquisas Vi algumas opinioes negativas microondas Brastemp pensei quase comprei outra marca ultima hora decidi comprar Brastemp E vou dizer coisa lindo apaixonada microondas Parabens Brastemp aparelho espetacular E outra coisa parabens Lojas Americanas entregou 2 dias Muito obrigada Alfa Vianna',
#  'Perfeito Resultado salao casa Otimo custo beneficio melhor marca ja vi mercado espero quebre rapido',
#  'Instalacao facil Material acabamento qualidades',
#  'Entrega dentro prazo recomendo otimo produto Nao irao arrepender',
#  'No dia 22 fevereiro recebi produto comprei comprado maior valor pago entregue E hoje entro contato Americanas FLIP loja parceira americanas ). E resolvem ainda ousadia dizer prazo reclamacoes havia expirado Como dia recebi entrei contato AVISO NAO COMPREM NADA NELA OU NAS PARCEIRAS PORQUE SE DER PROBLEMA VCS NAO TERAO QUEM RESOLVER E SO TERAO ABORRECIMENTOS POIS NENHUMA DAS DUAS SE IMPORTAM COM O CLIENTE EU DEIXEI DE COMPRAR NELAS AMERICANAS NAO FLIP NUNCA MAIS CLIENTES CUIDADO ELAS NAO NOS RESPEITAM ME SENTI LESADA POR EMPRESAS QUE SE DIZEM PARCEIRAS',
#  'Nao existe versao digital O produto vem codigo site caminho acessar Porem caminho valido Entrei site editora enviei questionamento Ate hoje sequer resposta',
#  'Senhores Muito errado oferecem pen drive preco acho interessante Preciso pendrive material faz parte trabalho Ocorre coloca CEP aponta valor entrega R 9 99 Ok correto ai agora entrega local pode entregar X frete correto Gostaria saber porque compro 6 pendrives obrigado pagar 6 fretes Isto propaganda enganosa parte site vendas Porque vezes anteriores comprei paguei apenas frete justo pois direcionando 6 lugares diferentes Preciso retorno parte E vez passada comprei pendrive 8 GB vieram embalagem totalmente diferente normal impressao produto segunda linha 5a linha totalmente padroes E ai trocar produto ainda pagar reajuste preco Isto pode ocorrer',
#  'Meu filho amou helice veio amarela veio branca tirando tudo ok Gostei',
#  'O produto chegou certinho tudo ordem lindo aparelho chegou 13 dias atraso duvidas ultima compra loja americanas devido descaso total resolver problema',
#  'A entrega rapida produto veio lacrado perfeitas condicoes A camera otima celular trava',
#  'Comprei carrinha 8 dias entregue ... msn diabqbentregou montamos percebemos q veio defeito costura lateral carrinho Liguei Central dafito ... disseram pra entrar contato transportadora A transportadora buscou produto ja 11 dias ninguem sabe qdo vai devolver outro carrinho Detalhe ja paguei produto !!!! Agora q vendo qdo chegar bebe conforto sercira netinha Pois comprei preciso produto ... agora ficar esperando Boa vontade transportadora ACHAR rastrear ... paciencia Ninguem nunca sabe nada E trouxe aqui ha comprou ... pagou recebeu produto deveria Palhacada',
#  'Otimo produto Super indico Entrega dentro prazo',
#  'Entrega super rapida livro bem embalado otimas condicoes alem lindo dentro Melhor livro li  Recomendo !!!',
#  'ENGANACAO NAO FUNCIONA NO BRASIL Esperei quase mes recebi telefone funciona pais No atendimento telefonico sujeita nome Renata absurdamente estupida ainda ameacou dizendo ligacao telefonica gravada Agora devolver esperar seculo estorno PROCUREM OUTRA LOJA !!!!! ja comprou faca processe',
#  'Livro boa leitura faixa etaria juvenil Conta sobre lingua portuguesa falada outros paises',
#  'A capa apresentacao legal comprei porque dizia descricao produto IMPERMEAVEL No entanto caiu liquido sobre capa manchou sofa',
#  'Estou encantada tanta eficiencia Amei chegou 10 dias antes prazo ... valeu apena frete caro rsrsrs satisfeita obrigada sempre bom comprar americanas',
#  'Produto otima qualidade !!! Material bom igual desenho Entrega prazo ...',
#  'Achei otimo produto design bonito prego bom Qualidade boa',
#  'Adorei ... otimo preco otimo computador Amo marca samsung',
#  'Gostei video game Nos faz relembrar jogos',
#  'Otimo material preco Super indico Ela bem reforcada material nao pinica corpo',
#  'Eu expliquei motivo ter cancelado pedido Depois dias atraso ninguem dar satisfacao ), entrei contato americanas informada produto ainda chegado estoque Deram novo prazo absurdo ). Obviamente cancelei pedido Um produto barato vendido varios sites comprei exatamente prazo entrega No dia cancelei pedido comprei loja fisica preco barato Decepcao propaganda enganosa',
#  'Bom Dia Nao compre produto falsificado americanas sequer telefone reclamar apenas mail Fui PROCON VOU PEDIR O LAUDO DO PRODUTO A AB Electrolux vou acionar advogado',
#  'Somos MG entrega bem tranquila liguei J loja agradecendo Obrigada',
#  'Voces deveriam tirar produto linha vendas A projecao fraca',
#  'Efetuei compra perfume dia 07 02 cobraram FRETE colocaram via PAC Correios hoje produto entregue sei aonde Nao volto comprar site americanas',
#  'Em valores melhor preco 128gb Resultado Aparelho bom entregue 10 dias antes previsto Tudo rapido tudo bom',
#  'Novamente cobrando case veio HD EXTERNO Americanas mail disse MONSTERTROK iria entrar contato mesma mandou comunicado enviaria dia 14 02 2018 hoje 23 02 2018 nada Cansei pois paguei vista Segunda dia 26 02 irei comunicar PROCOM colocarei revolta Facebook reclame aqui Nao vou pegar leve brincando cara bobo direito consumidor',
#  'Otimo produto realmente bacia pequena pra mim tamanho bom podia maior pouco',
#  'Sobre produto falar excelente recomendo vi algumas pessoas reclamando sobre barulho alto achei normal agora relacao frete pessimo demorou 30 dias pra receber produto casa paguei entrega rapida custo R 50 00 olha moro interior SP regiao facil acesso',
#  'Produto bom cumpre promete bastou seguir instrucoes fabricante forma adequada',
#  'pratico eficiente leve aprovado recomendo coletor deve limpo sempre usar porem pratico',
#  'Bem bom memoria boa bateria dura ate q bem .... flash selfie fica boa fotos',
#  'O celular bonito vale preco Faz tudo Samsung J7 faz Pense bem antes pagar furtuna Acho ter iPhones estatus outra coisa',
#  'Produto atendeu expectativas bonito bem funcional super satisfeito',
#  'EU comprei celular dia 26 04 chegar 4 5 ate hoje nao chegou porque cobraram 69 90 frete ... nao atualizam status diz ta preparado envio ... Decepcionadissimo americanas',
#  'Nao recebi produto avaliar ...............',
#  'Este produto fraco pois exatamente dois meses uso quebrou botao liga desliga O aparelho funciona finalidade fraco',
#  'Secador bom E entrega super rapida lojas americanas melhor loja internet',
#  'Otimo produto chegou antes prazo determinado Super recomendo',
#  'Excelente fixacao entrega antes prazo empresa parabens agilidade procedencia produto',
#  'Otimo produto apenas pedir pedir numero menos pois forma grande',
#  'Ainda aguardo dia americanas vai entregar sofa Espero dia ocorra Sigo sofa',
#  'Otimo produto entrega rapida Recomendo',
#  'Gostei produto entrega super rapida chegou tempo correto chegou ate antes prevista entrega',
#  'O produto otimo encantou esforco lojas Americanas entrega produto petzlife parece otimo depende prazo pra avaliacao Agradeco lojas Americanas preocupacao entrega principalmente satisfacao dada mim atraso Parabens equipe',
#  'Americanas entregou celular embalagem totalmente extraviada amassada embalagem externa produto rasgada dando abertura total alguem pegar produto Totalmente decepcionado empresa',
#  'produto bom pratico rapido recomendo produto',
#  'oito nucleos processamento so sera usado alta tecnologia invertem cabo alimentacao pra q dai nao pra conectar drones fala q luz esterna nao verdade dia nao consegue ver imagens drone pra vai usar 64giga fotos wattsapp serve restante pode esquecer so nao devolvi pq ja mandado pegaram volta perdi 150 reais pq vale nao aceito boleto perde desconto vc comprando produto preciso pra trabalhar melhor comprar mercado livre q vc pode pedir detalhes vendedor pra ter aparelho pra watts so pra drone melhor comprar BLU 250 reais total indignacao quiserem podem cortar conta ja compro so boleto pra nao incomodar nisso',
#  'Excelente Verdadeiramente cinema casa Muito satisfeito Recomendo compra A entrega feita rapidamente bem antes prazo estipulado',
#  'O produto chegou 3 dias pago Muito rapido eficiente',
#  'Recomendo lindo funcional agua bem gelada',
#  'Recomendo TV surpreendeu positivamente Estou satisfeito',
#  'Atendeu esperava O material resistente Foi imaginei Recomendo',
#  'Produto chegou perfeitas condicoes infelizmente funcionou home tieter Sony',
#  'Porem falta compromisso cliente fez cancelar compra Inadimissivel pre venda entrega prevista 7 5 NF havia gerado informacao recebi mail gerado 26 4 Pre venda Americanas nunca',
#  'Excelente produto preco imbativel disponibilizado Americanas As impressoes boas grande clareza Muito bom acabamento principalmente tecnologia agregada Wi Fi simplificando tudo dia dia uso fios Ate agora gostando bastante impressora recomendaria amigos Parabens Americanas envio rapido 5 dias uteis Piracicaba SP',
#  'Perfeita unico defeito alcanca fundo entao pra fazer receita menos 3 ovos clara neve exemplo ).',
#  'O produto exatamente procurando entrega infinitamente rapida imaginava',
#  'Tive pequeno atraso entrega assim chegou produto fiquei bastante satisfeita compra',
#  'Este produto veio defeito pedi trocar ninguem da solucao sempre confiei America desta vez pisaram bola vou perder dinheiro vou comprar neste',
#  'Na primeira lavagem antes usar produto soltou mto deixando aspecto toalhas gastas',
#  'O jogo Monaco composto cinco panelas panela pressao veio tampa vidro levemente amassada dificulta encaixe perfeito tampa panela A panela pressao pertence jogo longe Apesar panela pressao Tramontina espessura aluminio bem fina jogo Monaco Porem vc avaliar custo beneficio marca dependendo quanto vc utiliza panela pressao vale pena Dependendo vale Melhor comprar jogo Monaco bom separado comprar panela pressao',
#  'O celular excelente prazo entrega cumprido Mesmo pagando taxa rapida entrega demorou 3 semanas',
#  'Produto excelente joguei testei assisti videos 4k pois PC placa video gera 4k otimo design bonito cumpre todas necessidades aconselho mim supriu todas necessidades recomendo',
#  'Mimiatura material plastico qualidade ruim A portinha abre totalmente ...',
#  'show bola gostei d procurando tempos',
#  'Excelente produto satisfeita Recomendo',
#  'Gostei desse produto recomendo duvida Obrigada',
#  'O preco razoavel entrega super rapida O produto qualidade eficaz super recomendo',
#  'Seguindo passo corretamente funciona perfeitamente',
#  'Comprei bike black friday menos mes uso roda traseira comecou ter contato quadro Estou insatisfeito pois paguei caro produto conta disso entrei contato fornecedor onde orientado bicicleta carro moto requerem revisoes basicas revisoes ocorrem menos mes Desculpe convenceu Alem disto orientado problema contempla garantia momento algum site instrucoes concedidas menciona devo fazer revisoes basicas instrucoes conservacao bike Nao recomendo fornecedor pensarei 2 vezes antes voltar fazer aquisicoes junto plataforma Americanas',
#  'Uso perfume tempo ultimo comprei aqui loja Prado Belli totalmente falso cheiro alcool puro Uma porcaria !!!',
#  'Comprei experimentar gostei vez caminhoneiro gostaria ter GPS dinheiro comprar marca melhor entao comprei Discovery gracas Deus ta ajudando hoje E ainda cima TV ...',
#  'Estou satisfeito compra A Tv imaginava Super leve peso ), varias funcoes qualidade imagem som perfeitos Estou satisfeito tbm Americanas Entregou produto antes prazo atendimento bom Parabens !!!',
#  'Bom produto Bonito leve pratico Comprei pra usar acampamento ainda chance usar Mas testei quarto ilumina bem A graduacao iluminacao boa Nao testei quanto tempo dura carga Carrega rapido Recomendo',
#  'Top one vendas loja bonita reforcada alto padrao certeza excelente escolha entrada casa modelo pivotante deixa todo charme gosta receber bem !!!',
#  'Realizei compra dia 10 04 18 hoje dia 09 05 18 recebi produto',
#  'Me surpreendeu montado lindo ficou clique material bom super satisfeita chegou bem antes previsto 3 dias comprado',
#  'otimo produto recomendo compra tudo certo prazo tambem',
#  'realmente percebe diferenca primeira aplicacao',
#  'Produto MQ Professional E imitacao barata outra marca',
#  'Produto otimo entrega antes previsto bom',
#  'Entrega dentro prazo produto excelente satisfeita compra',
#  'E otimo produto fiz comentarios panela eletrica',
#  'Comprei presentear agradou bastante Resistente confortavel',
#  'Gostei alem ter ficado lindo Facilita digitacao textos',
#  'So uso panelas pressao dessa marca E nunca problemas Entrega prazo Recomendo marca site',
#  'Produto excelente ... entrega rapida tempo agendado',
#  'Porque ninguem da retorno comprei 10 dias gera nota fiscal socorro alguem Americanas retorno Assombroso mal atendimento',
#  'Poderia ter controle volume Gostei graves encaixa ouvido confortavelmente',
#  'Amei TV boa Era sonho Simplesmente tudo otimas condicoes',
#  'Produto bom vendedor atencioso obrigada atencao',
#  'excelente cumpre todas funcoes ,,, super recomendo',
#  'Super recomendo entrega rapida produto boa qualidade',
#  'O relogio deu defeito 3 deg dia Lamentavel Gostaria substituido produto pois custo baixo deve justificar conserto alguns " leds " cristal liquido Atenciosamente Bernardo',
#  'Macio resistente otimo custo beneficio Entrega dentro prazo',
#  'Produto bom Demora pra fritar alimentos ficam show bola Gostei A entrega embora prazo achei demorando Ja melhor',
#  'Qual marca to querendo compra fala marca anucio',
#  'Os unicos contras rede repetida pode ter outro nome rede porem senha q mesma bom produto Consegui ter nova rede novo nome nova senha configurando repetidor outro nome apos configurar liguei cabo rede rj 45 porta liguei outro roteador modo ap Resumindo duas redes porem repetidor muda senha supre q preciso',
#  'O produto veio bem embalado antes prazo E livro bom diagramas desequilibrios comuns Recomendo consulta',
#  'Quanto tempo dura cabelo Esse produto pode passar couro cabeludo causa queda cabelo',
#  'Nao recomendo Nao da pra usar camisa transparente pq listado E fica mto folgado cintura justo busto quadril',
#  'Produto entregue dentro prazo surpreendeu eficiencia Satisfeta recomendo',
#  'Muito bom bonito versatil Tem manual instrucoes util',
#  'O produto atendeu expectativas chegou prazo previsto',
#  'Veio conforme especificacoes chegou antes prazo',
#  'Fone bom preco Dentro expectativas',
#  'Produto bom chegou antes prazo recomendo site',
#  'Boa tarde Fiz pedido ventilador 220v aqui vc pedindo avaliar produto jeito pedi Outra coisa ainda recebi produto casa .!',
#  'Amei Produto excelente qualidade silencioso vento bem forte muto satisfeita produto',
#  'Muito boa colecao !! Recomendo gosta romances quentes ...',
#  'Se soubesse comprar algo inicio dezembro presentear ente Natal iria receber Dps ano novo comprado Aniversario pai dia 04 02 chega la Descaso total Jadlog americanas futfanatics A informacao entregam cep deveria vir simulacao compra duas semanas apos pagamentos Ja acionei americanas duas vezes visto farei terceira vez',
#  'Produto excelente Estou acostumando E bem diferente anterior usei 20 anos Ja percebi vou entender bem Americanas sempre tudo bom seriedade atencao rapidez A transportadora daqui Joinville SC ), otima',
#  'Ao propoes fazer produto otimo gela bem outras funcionalidades entao sabia somente ventilar desumidificar pra mim bem uteis',
# ...
#  'Dois meses antes desse tempo aparelho parou funcionar O atendimento vendedor ruim certificado garantia Nao comprem reclamem Americanas',
#  'Muito boa Tv configuracao facil Resolucao Maravilhosa',
#  'Comprei 30 dias ainda consta status aguardando nota fiscal .. ainda saiu fabricante ... 1 mes q paguei Sinceramente achei parceiro tricae q eh responsavel entrega desorganizado Como vc compra produto demora 30 dias emitir nota fiscal Desse jeito vai demorar 30 dias entregar total 60 dias receber produto Um absurdo',
#  'Relogio Original embalagem impecavel chegou prazo !! Recomendo',
#  'Se quer produto tempo uso adquira Ugly Stick',
#  'Comprei produto 12 fevereiro hoje dia 14 marco ainda recebi produto ... certeza comprarei nada neste site',
#  'Parabens equipe Americanas Como sempre seriedade compromisso',
#  'Sem problemas Funcionando bem Intercomunicador excelente',
#  'produto chega enrolam voce faz voce esperar dias frete cancelam produto',
#  'Muito bom jogo recomendo otimos graficos jogabilidade',
#  'Otima qualidade correspondeu expectativa Entrega antes prazo agradeco americanas',
#  'Produto otima qualidade bonito imagens',
#  'Recebi computador HD estragado computador inutilizavel ja mandei varios tickets parar atendimento Americanas iriam encaminhar loja enviou pedido loja Comprebel ficaram responder 48 horas ja passou varios dias nada resposta Fiquei prejuizo loja suporte',
#  'Chegou antes prometido aparelho espetacular realmente superou espectativas',
#  'O produto pessimo Dell E lento iniciar ... teclado pequeno digitar ... licenca office provisoria ... fica mes ... apos vc e obrigado comprar licenca mandar alguem instalar ... porcaria produto',
#  'Achei excelente qualidade podem comprar medo',
#  'celular pratico facil idosos recomendo compra Entrega antes prazo',
#  'O produto chegou antes prazo atendendo expectativas',
#  'Me surpreendeu muitos aspectos primeiro LG gostei So bateria poderia durar pouco valendo',
#  'Excelente produto recomendo entrega prazo sempre compro americanas sempre satisfeito',
#  'Recebi produto tempo Record Faltando 20 dias data prevista Meu filho amou',
#  'A capa linda arranha facilmente Se encaixa perfeitamente celular parece oferecer boa protecao Amei',
#  'Otimo livro facil leitura licao pra levar pra vida inteira',
#  'O produto original diz anuncio Vem embalado papel pao Nao carrega 100 %. Cuidado comprar produtos parceiros Americanas Aparentemente avaliados criteriosamente Quem diria Americanas chegaria baixo nivel Deixei comprar Mercado Livre medo cair maos picaretas olha acontece Americanas coloca maos',
#  'Produto boa qualidade preco extremamente acessivel',
#  'As cores interessantes porem lavarmos cuecas desfiam toda Como novelo la',
#  'Entrega bem antes prazo anunciado otimo custo beneficio boa qualidade produto',
#  'lindo painel qualidade excelente chegou antes prazo adorei',
#  'Produto ruim usei poucos dias deu defeito',
#  'O produto entregue data antes game excelente qualidade !!!',
#  'bom super recomendo otima pratica eficiente',
#  'Chegou rapido problema entrega gostei produto',
#  'Minha filha adorou gostou Recomendo produto',
#  'Recomendo site O produto entregue certo antes prazo estabelecido',
#  'Antes fechar pedido cuidado ligar central atendimento confirmar informacoes site atendente tom jocoso disse site parceiro Americanas assumem responsabilidade Resumindo entregaram entao cancelaram pedido nome reclamei site atendente ligou informar razao cancelamento feito pois informacoes site poderiam cumpridas Que vergonha Estou aguardando ver menos farao estorno TB mentira',
#  'Entrega rapida produto atendeu expectativas',
#  'produto bom pois enorme poder retencao liquidos garante menos trocas bebe fica sempre seco evitando assaduras Pena cara',
#  'Bateria dura 27 ja desliga ainda dura somente umas 7 horas vai',
#  'Nao posso avaliar produto recebi acho falta respeito grande forma sendo tratado problema enfrentando receber aparelho celular faz 30 dias comprei ai vem mensagem faca avaliacao precisam organizados aprender resolver problemas conforme relatando clientes consumidor',
#  'Jogo otima condicoes melhor preco chegou antes data prevista Super recomendo',
#  'Gostei ... pratico Ajuda bastante limpeza casa',
#  'Nao gostei amassa volta tamanho normal Quando deita faz formato deitado apenas amassa',
#  'Excelente produto .... Fantastico acabamento ... Bem resistente otima qualidade',
#  'A entrega bem antes prazo otimo atendimento super recomendo',
#  'O mouse bom boa ergonomia otima qualidade',
#  'Ja uso faz tempo E creme faz diferenca Recomendo',
#  'Um livro excelente conteudo facil simples entendido aplicado ... Ira surpreender pois Raio X trajetoria profissional muitos Mundo',
#  'Tive Samsung A7 Mirage 91s deixou desejar nada relacao softwares Tem alguns pontos melhorar tempo bateria memoria expansiva porem aparelho surpreende qualidade valor ofertado Gostei recomendo',
#  'Imagem escura mexer bastante configuracoes cheguei imagem satisfatoria Otima imagem netflix otima conexao via wifi rapida controle fraco imagem canais tv aberta fechada permaneceram imagem pouco escura melhor fabrica mexer configuracoes De modo geral satisfeito primeira 4k',
#  'conhecia produto comprei recomendo',
#  'poucas palavras pele crianca primeiro creme revigorou marcas trouxe iluminacao pele ... uso bem pouquinho todo dia noite pele revigorada Adoro produto Helene Deon Parabens obrigado recomendo dor cirurgia melhora profunda natural ).',
#  'bom dia peninha queria mt produtos frete fica mt caro acabei retirando td carrinha conta frete acho absurdo valores',
#  'Esse produto encontra barato pq sendo vendido defeito Comprei pq acreditei nome loja americana porem ligou apenas duas vezes possivel instalar canais chegou embalado perfeitamente arranhoes tracos caiu ., porem funciona liguei autorizada dois dias chegou ate agora nada ... insatisfeita',
#  'Nao recebi ainda consegue informar qd vai chegar ??',
#  'Cuidado golpe paguei 1700 00 recebi 250 00 cuidado !!!',
#  'Excelente aparelho entrega super rapida O Celular surpreendeu melhor esperava Comprar Americanas sempre tranquilo',
#  'Comprei .... Instalei .. O botao acionado sair agua ...... Quebrado ..... To aguardo troca',
#  'Produto diferente comprei Marca diferente Metragem cabo diferente Nao recomendo comprar Perderam cliente',
#  'Produto qualidade superando expectativas entrega rapida Recomendo ******',
#  'O frete custa Nem teclado custa preco frete',
#  'Produto pouco barulhento menos bem imaginei',
#  'Minha sobrinha adorou ficou feliz recomendo entrega antes prazo bom',
#  'Encaixou perfeitamente porta veio rapido otimo',
#  'Otimo brinquedo filha amou produto qualidade entrega pontual',
#  'O carrinho bom Leve dentro possivel ), compacto fechado fechamento facil montagem desmontagem simples Muito melhor marcas famosas pesados fechados quase reduzem volume ocupado Uma excelente surpresa investimento valeu pena bebe conforme bom similar demais mercado',
#  'Otimo custo beneficio entregue certinho dentro prazo',
#  'Fralta boa Otima absorcao deixa pele sequinha Muito obrigada huggies theinsiders campanha huggiessofttouch theinsidersbrasil',
#  'Comprei panelas esperei chegarem servico entrega otimo chegou antes esperado achei ia demorar ), panelas vieram defeito Assim colocadas sobre fogo trincaram esmalte descascaram alem soltar cheiro horrivel produto quimico Solicitei devolucao bem atendida Mas indico compra',
#  'O produto momento dentro perspectivas Televisor otimo Recomendo !!!',
#  'Entrega super rapida Bem antes prazo Produto bom Minha filha dorme anjo nele Usamos pra passear',
#  'ganhei escova presente usei duas vezes mesma esquentando demais gostaria saber poderia resolver problema',
#  'Otimo travesseiro super macio confortavel Vendedor excelente recomendo compra !!!',
#  'Maravilhoso rapido excelente camera flash bom',
#  'otimo produto cumpre oq promete chegou antes prazo tudo certo',
#  'O Frete caro sofa .. Nunca vi nada absurdo .... Desanima qualquer comprar',
#  'Faco quimica tempo cabelo ressecado Na primeira vez uso pareceu milagre Rsrs Cabelos macios brilho',
#  'Comprei frigideira pensando iria boa fritar ovos hamburguer ontem fiz teste decepcao total tanto hamburguer quanto ovos grudaram comecou queimar lateral fundo frigideira ficou borra deixar molho Ai continuar fritar ovos hamburguer usei velha frigideira antiaderente excelente qualidade NAO RECOMENDO COMPRAR FRIGIDEIRA DE FERRO BATIDO',
#  'E UM PRODUTO REGULAR MAIS DA PRA USAR FICA NO CANTINHO NAO VAI SER MUITO USADO ESTAR BOM',
#  'BOM ACHO MUITO RUIM QUANDO SOLICITAMOS UM PRODUTO E NOS ENVIAM OUTRO ISSO E MUITO DESAGRADAVEL Nao recebi produto sim CICATRICURE GEL PARA CICATRIZES E ESTRIA NAO E O PRODUTO DO QUAL EU COMPREI E ESTAVA ESPERANDO MUITO INSATISFEITA RESOLVI NAO EFETUAR A TROCA POIS ISSO ME CAUSARIA MAIS TEMPO E INSATISFACAO',
#  'Alem bonito copo GIGANTE perfeito pra fazer vitaminas',
#  'O tamanho liquidificador otimo copo acrilico fragil Esperava Liquidificador resistente',
#  'Comprei pra dar presente .. vou presentear alguem csixa toda rasgada Manual todo ingles',
#  'Aparelho leve bateria demora descarregar camera top amei',
#  'Nao recebi produto !!! A credito nao necessite escrever nada NAO RECEBI O PRODUTO ja basta',
#  'Entrega rapida produto bem embalado produto maravilhoso recomendo',
#  'O produto si excelente veio defeito fica piscando direto parar trocar',
#  'Comprei presente aniversario pro pai gostando celular tanto recomendo caso alguem queira compra lo',
#  'Queria saber faco escolher cor encosto',
#  'Gente recomendo ... produto otima qualidade pra jogar tranquilo ... tanto criancas tbm adultos ... chegou bem antes prazo parabens lojas Americanas casa bilhar',
#  'Estou esperando ainda recebi ... favor resolver rapido',
#  'Fiz compra produto dia 20 04 chegou hoje dia 03 05 Fiz questao pagar caro produto acreditava original inves gastar 50 reais muitos vendidos internet surpreendi falta qualidade Para comecar fonte veio embalada dentro plastico bolha ter caixa algo mostrasse produto usado Ao compara lo fonte original possuo casa observei mesma possui logo Xbox fabricada Microsoft O peso fonte menor original voltagem escrita especificacoes simplesmente RISCADA A CANETA Que tipo confianca produto entregue deste jeito passa consumidor Eu paguei produto ORIGINAL entregam produto escrito chines corresponde prometido Estou solicitando troca hoje dia recebi produto deixo aqui aviso todos tentarem comprar deste vendedor possui telefone contato',
#  'Otimo produto facilita funcionalidade tv box',
#  'Comprei microondas 3 anos uso descascou tinta dentro sempre usamos produtos indicados manual limpeza',
#  'E resistente isolante material cheiro forte Precisa lavada algumas vezes antes usar',
#  'N posso dar opiniao pq ainda recebi produto cuja entrega prevista dia 10 04 !!!!!!',
#  'O PRODUTO E OTIMO MAS A ENTREGA FOI PROMETIDA PARA 12 04 18 E AGORA MUDOU PARA DEPOIS DE 23 04 18',
#  'O prazo entrega passou ainda recebi produto',
#  'Perfeito funciona bem otima luminosidade',
#  'Uso relaxamento anos adoro Facil aplicar cheiro nenhum O cabelo fica otimo',
#  'A Informacao Produto Errada Pois la Esta Informacoes Faca ..',
#  'E produto superou expectativas Amei uso quebra galho super recomendo',
#  'Leve facil limpar ideal pequenos trabalhos',
#  'Gostei Estou satisfeita tanto produto quanto entrega Parabens',
#  'Bom bonito contudo veio pouco arranhado menos n demorou produto correto',
#  'Acontece cerca 70 brasileiros sabem usar smartphones tao procuram informar sobre Muitos sabem basicos aparelhos memoria RAM processador hardware Enchem aparelhos tudo enquanto porcaria app encontram play store removem lixos apos navegacoes internet uso app limpam caches apps instalam app pesados Facebook Snapchat entopem smartphones jogos pesados veem comentarios idiotas Querem smartphone 2GB memoria RAM suporte varios jogos pesados alem apps pesados Facebook Instagram Snapchat whatsapp travem',
#  'Produto defeito encaminharei garantia',
#  'produto funcionou perfeitamente ..... 8 dias canais todos travados',
#  'Bom custo beneficio gfdgsdf gsdfg sdfgsdfg sdfg sdfg sdfgsdf',
#  'Adorei super recomendo .. chegou bem antes prazo !!',
#  'Primeiros meses tudo otimo mes vencer garantia comecou desligar sozinha Mandei autorizada repararam defeito porem dois meses garantia tv comecou defeito',
#  'foto fica ruim comprei nao olhei nao fles',
#  'Produto excelente qualidade cumpre promete recomendo pode adquirir medo !!! Muuuuuuito bom !!! Vc vai arrepender !!!',
#  'TV Excelente imagem som funcionalidades A entrega rapida Recomendo todos',
#  'Realmente succao sopro fortes fiquei impressionado Produto resistente bem acabado extensao bem grande enfim reclamar',
#  'Ainda recebi produto Assim receber entregue talvez possa avaliar',
#  'Comprei desse fevereiro ano passado deu problema 3 meses entrei contato assistencia tecnica dentro 30 dias consertou devolveu celular perfeitas condicoes recomendo pois celular bom umas fotos excelentes',
#  'Ja fiz avaliacao disse porcaria americanas deveria comercializar sub produtos esse',
#  'Comprei dois meses Um dia ligar tela parecia trincada Levei autorizada disseram marca comum acontecer Que veio pessoas tirar caixa trincou tela Agora pagando concerto Nao recomendo',
#  'Otimo produto excelente tempo entrega recomendo',
#  'Se soubesse quao bom comprado antes Custo beneficio excelente',
#  'Por bagatela 3 100 reais quero logo 10 melhor de logo 50 promocao posso perder',
#  'Para quer cadeira pratica indico Fixa bem leve Nao problemas c BB nela',
#  'Nao gostei porque passou prazo ligar saber aconteceu pois rastreio dizia Fui informada produto extraviado Cancelaram pedido fa zero outro E segundo pedido chegou direito',
#  'Esperando troca pois protudo veio co Defeito',
#  'Gostei otimo custo beneficio correspondeu expectativas',
#  'GOSTE MUITO RECOMENDO E IREI COMPRAR OUTRO PRA MINHA VARANDA',
#  'A forma tema abordado ajuda negociacoes deixar enganar falsas promessas inducoes psicologicas seculo XXI Leitura ensinamentos proveitosos Vale pena ler',
#  'So acho Senhores deveriam cobrar frete categoria comprados livros brinquedos otros pois cada coisa q comprei frete',
#  'produto entregue dentro prazo prometido Gostei produto',
#  'Comprei produto hora compra mostrava chegaria 11 dias prazo outro che chegou antes data prevista Recebi hoje 4 maio 18 Veio mal embalado tanto conseguia ver produto dentro fiquei super ansiosa logo abrindo montar Para decepcao base esfregao sistema articulado vai 15 deg, veio defeito Ele fica reto consiga encaixar tanto refil quanto encaixar base mop interior balde consigo molhar menos girar fazer centrifugacao E site opcao fazer troca produto devolucao dinheiro Vale Decepcao total',
#  'Bom celular gostei memoria boa E tela d 5 otimo p assistir TV',
#  'Super atendeu expectativas Sofa confortavel espacoso lindo contar chegou bem antes prazo estimado preco bem acessivel',
#  'Vi alguns comentarios aqui malhando produto valor oferece acho mto bom aparelho tantas funcoes ainda consegui utilizar imagem digital perfeita som realmente diferente bem ajustado equalizador poucas tvs possibilidade nada parece radinho pilha souber usar fica dificilimo Se net ruim antena idem tv faz milagres !! E dar carro formula 1 mao pessoa nunca dirigiu',
#  'O produto chegou mau embalado loja origem Por tratar produto delicado deveriam ter cuidado embalar',
#  'chegou rapido celular lindo jeito queria Fiquei satisfeita ...',
#  'Muito bom produto entrega antes prazo final Muito bom parabens',
#  'Me sinto ROUBADA paguei produto envio recebi Amanha emsmo vou tomar providencias legais ... PROCON PEQUENAS CAUSAS N cao recebi ligacao Americanas sabem produto NAO FOI ENTREGUEha varios dias',
#  'Entrega prazo preco excelente produto qualidade Gostei',
#  'Comprei produto Americanas 16 2 prazo entrega fixado 20 2 Ate hoje 7 3 produto entregue apesar ter feito todas reclamacoes possiveis site Americanas existe telefone falar ), ter postado reclamacao RECLAME AQUI Ate hoje recebi produto simples informacao Quem comprar canal corre serio risco lesado sendo',
#  ...]

# %%
stopwords_sem_acento = [unidecode.unidecode(texto) for texto in pontuacao_stopwords]
stopwords_sem_acento
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  'a',
#  'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'as',
#  'ate',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'eramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'esta',
#  'estamos',
#  'estao',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estavamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiveramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivessemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'foramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fossemos',
#  'fui',
#  'ha',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hao',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houvera',
#  'houveram',
#  'houveramos',
#  'houverao',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveriamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvessemos',
#  'isso',
#  'isto',
#  'ja',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nao',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'sao',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'sera',
#  'serao',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seriamos',
#  'seu',
#  'seus',
#  'so',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'tambem',
#  'te',
#  'tem',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'tera',
#  'terao',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teriamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tinhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiveramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivessemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'voce',
#  'voces',
#  'vos']

# %%
avaliacoes["texto_sem_stopwords_e_pontuacao_e_acentos"] = sem_acentos


frase_processada = list()
for avaliacao in avaliacoes.texto_sem_stopwords_e_pontuacao_e_acentos:
  nova_frase = list()
  palavras_texto = token_pontuacao.tokenize(avaliacao)
  for palavra in palavras_texto:
    if palavra not in stopwords_sem_acento:
      nova_frase.append(palavra)
  frase_processada.append(' '.join(nova_frase))

avaliacoes["texto_sem_stopwords_e_pontuacao_e_acentos"] = frase_processada

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

def treinar_modelo(dados, coluna_texto, coluna_sentimento):
  vetorizar = CountVectorizer(max_features=100)
  bag_of_words = vetorizar.fit_transform(dados[coluna_texto])
  treino, teste, classe_treino, classe_teste = train_test_split(bag_of_words,
                                                                dados[coluna_sentimento],
                                                                stratify=dados[coluna_sentimento],
                                                                random_state = 71)
  regressao_logistica = LogisticRegression()
  regressao_logistica.fit(treino, classe_treino)
  return regressao_logistica.score(teste, classe_teste)

# %%
print(treinar_modelo(avaliacoes, "texto_sem_stopwords_e_pontuacao_e_acentos", "polarity"))
# Out:
# 0.8824745821127004

# %%
avaliacoes.head()
# Out:
#                                          review_text  polarity  \
# 0  Bem macio e felpudo...recomendo.  Preço imbatí...       1.0
# 1  Produto excepcional!  recomendo!!! inovador e ...       1.0
# 2  recebi o produto antes do prazo mas veio com d...       0.0
# 3  Bom custo beneficio. Adequado para pessoas que...       1.0
# 5  ótmo produto atendeu as expectativas, a entreg...       1.0
#
#                                  texto_sem_stopwords  \
# 0  Bem macio felpudo...recomendo. Preço imbatível...
# 1  Produto excepcional! recomendo!!! inovador gos...
# 2  recebi produto antes prazo veio defeito trava ...
# 3  Bom custo beneficio. Adequado pessoas fazem us...
# 5  ótmo produto atendeu expectativas, entrega oco...
#
#                      texto_sem_stopwords_e_pontuacao  \
# 0  Bem macio felpudo ... recomendo Preço imbatíve...
# 1  Produto excepcional recomendo !!! inovador gos...
# 2  recebi produto antes prazo veio defeito trava ...
# 3  Bom custo beneficio Adequado pessoas fazem uso...
# 5  ótmo produto atendeu expectativas entrega ocor...
#
#            texto_sem_stopwords_e_pontuacao_e_acentos
# 0  Bem macio felpudo ... recomendo Preco imbative...
# 1  Produto excepcional recomendo !!! inovador gos...
# 2  recebi produto antes prazo veio defeito trava ...
# 3  Bom custo beneficio Adequado pessoas fazem uso...
# 5  otmo produto atendeu expectativas entrega ocor...

# %%
from wordcloud import WordCloud

todas_avaliacoes = [texto for texto in avaliacoes.texto_sem_stopwords_e_pontuacao_e_acentos]
todas_palavras = ' '.join(todas_avaliacoes)
nuvem_palavras = WordCloud(width=800, height=500,
  max_font_size=110,
  collocations=False).generate(todas_palavras)

# %%
def word_cloud_neg(dados, coluna_texto):
  texto_negativo = dados.query("polarity == 0")
  todas_avaliacoes = [texto for texto in texto_negativo[coluna_texto]]
  todas_palavras = ' '.join(todas_avaliacoes)

  plt.figure(figsize=(10,7))
  plt.imshow(nuvem_palavras, interpolation='bilinear')
  plt.axis("off")
  plt.show()

# %%
def word_cloud_pos(dados, coluna_texto):
  texto_positivo = dados.query("polarity == 1")
  todas_avaliacoes = [texto for texto in texto_positivo[coluna_texto]]
  todas_palavras = ' '.join(todas_avaliacoes)

  plt.figure(figsize=(10,7))
  plt.imshow(nuvem_palavras, interpolation='bilinear')
  plt.axis("off")
  plt.show()

# %%
word_cloud_neg(avaliacoes, "texto_sem_stopwords_e_pontuacao_e_acentos")

# %%
word_cloud_pos(avaliacoes, "texto_sem_stopwords_e_pontuacao_e_acentos")

# %%
frase_processada = list()
for avaliacao in avaliacoes.texto_sem_stopwords_e_pontuacao_e_acentos:
  nova_frase = list()
  avaliacao = avaliacao.lower()
  palavras_texto = token_pontuacao.tokenize(avaliacao)
  for palavra in palavras_texto:
    if palavra not in stopwords_sem_acento:
      nova_frase.append(palavra)
  frase_processada.append(' '.join(nova_frase))

avaliacoes["texto_sem_stopwords_e_pontuacao_e_acentos"] = frase_processada

# %%
word_cloud_neg(avaliacoes, "texto_sem_stopwords_e_pontuacao_e_acentos")

# %%
word_cloud_pos(avaliacoes, "texto_sem_stopwords_e_pontuacao_e_acentos")

# %% [markdown]
# ## Aula 04

# %%
from nltk.stem import RSLPStemmer
stemmer = RSLPStemmer()
# reduz as palavras a uum radical comum e reduz a qunatidade de palavras
# produtos - produto - Produto = produto
# correr, correndo - correria = correr
# trás mais semanatica a frequencia de palavras.
# SLPS é exclusivo do Portugues, para outras linguagens precisa de outra
# biblioteca

# %%
avaliacoes.head()
# Out:
#                                          review_text  polarity  \
# 0  Bem macio e felpudo...recomendo.  Preço imbatí...       1.0
# 1  Produto excepcional!  recomendo!!! inovador e ...       1.0
# 2  recebi o produto antes do prazo mas veio com d...       0.0
# 3  Bom custo beneficio. Adequado para pessoas que...       1.0
# 5  ótmo produto atendeu as expectativas, a entreg...       1.0
#
#                                  texto_sem_stopwords  \
# 0  Bem macio felpudo...recomendo. Preço imbatível...
# 1  Produto excepcional! recomendo!!! inovador gos...
# 2  recebi produto antes prazo veio defeito trava ...
# 3  Bom custo beneficio. Adequado pessoas fazem us...
# 5  ótmo produto atendeu expectativas, entrega oco...
#
#                      texto_sem_stopwords_e_pontuacao  \
# 0  Bem macio felpudo ... recomendo Preço imbatíve...
# 1  Produto excepcional recomendo !!! inovador gos...
# 2  recebi produto antes prazo veio defeito trava ...
# 3  Bom custo beneficio Adequado pessoas fazem uso...
# 5  ótmo produto atendeu expectativas entrega ocor...
#
#            texto_sem_stopwords_e_pontuacao_e_acentos
# 0  bem macio felpudo ... recomendo preco imbative...
# 1  produto excepcional recomendo !!! inovador gos...
# 2  recebi produto antes prazo veio defeito trava ...
# 3  bom custo beneficio adequado pessoas fazem uso...
# 5  otmo produto atendeu expectativas entrega ocor...

# %%
frase_processada = list()
for avaliacao in avaliacoes.texto_sem_stopwords_e_pontuacao_e_acentos:
  nova_frase = list()
  palavras_texto = token_pontuacao.tokenize(avaliacao)
  for palavra in palavras_texto:
    if palavra not in stopwords_sem_acento:
      nova_frase.append(stemmer.stem(palavra))
  frase_processada.append(' '.join(nova_frase))


avaliacoes["texto_stemmizado"] = frase_processada

# %%
treinar_modelo(avaliacoes, "texto_sem_stopwords_e_pontuacao_e_acentos", "polarity")
# Out:
# 0.8707565052559021

# %%
treinar_modelo(avaliacoes, "texto_stemmizado", "polarity")
# Out:
# 0.8852662415991729

# %%
word_cloud_neg(avaliacoes, "texto_stemmizado")

# %%
word_cloud_pos(avaliacoes, "texto_stemmizado")

# %%
grafico(avaliacoes, "texto_stemmizado", 10)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

frases = ["Este produto é muito bom", "Este produto é muito ruim"]
tfidf = TfidfVectorizer(lowercase=False, max_features=100)
caracteristicas = tfidf.fit_transform(frases)

pd.DataFrame(
    caracteristicas.todense(),
    columns=tfidf.get_feature_names_out()
)
# Out:
#        Este       bom     muito   produto      ruim
# 0  0.448321  0.630099  0.448321  0.448321  0.000000
# 1  0.448321  0.000000  0.448321  0.448321  0.630099

# %%
tfidf_tratados = tfidf.fit_transform(avaliacoes.texto_stemmizado)
treino, teste, classe_treino, classe_teste = train_test_split(tfidf_tratados,
                                                              avaliacoes.polarity,
                                                              random_state = 71)

regressao_logistica = LogisticRegression()
regressao_logistica.fit(treino, classe_treino)
acuracia_tfidf = regressao_logistica.score(teste, classe_teste)
acuracia_tfidf
# Out:
# 0.8871962777873513

# %%
from nltk import ngrams

frase = "Comprei um ótimo produto."
frase_separada = token_por_espaço.tokenize(frase)
pares = ngrams(frase_separada, 2)
list(pares)
# Out:
# [('Comprei', 'um'), ('um', 'ótimo'), ('ótimo', 'produto.')]

# %%
tfidf = TfidfVectorizer(lowercase=False, ngram_range = (1,2))
vetor_tfidf = tfidf.fit_transform(avaliacoes.texto_stemmizado)
treino, teste, classe_treino, classe_teste = train_test_split(vetor_tfidf,
                                                              avaliacoes.polarity,
                                                              random_state = 71)

regressao_logistica = LogisticRegression()
regressao_logistica.fit(treino, classe_treino)
acuracia_tfidf_ngrams = regressao_logistica.score(teste, classe_teste)
acuracia_tfidf_ngrams
# Out:
# 0.9364811304497673

# %%
tfidf = TfidfVectorizer(lowercase=False)
vetor_tfidf = tfidf.fit_transform(avaliacoes.texto_stemmizado)
treino, teste, classe_treino, classe_teste = train_test_split(vetor_tfidf,
                                                              avaliacoes.polarity,
                                                              random_state = 71)

regressao_logistica = LogisticRegression()
regressao_logistica.fit(treino, classe_treino)
acuracia_tfidf = regressao_logistica.score(teste, classe_teste)
acuracia_tfidf
# Out:
# 0.932241943822161

# %%
pesos = pd.DataFrame(
  regressao_logistica.coef_[0].T,
  index = tfidf.get_feature_names_out()
)

pesos.nlargest(10, 0)
# Out:
#                    0
# otim       14.925728
# excel      14.384492
# bom        10.057124
# perfeit     9.367302
# ador        9.169407
# ame         7.164503
# satisfeit   7.032553
# lind        6.923753
# maravilh    6.695739
# rap         6.217399

# %%
pesos.nsmallest(10, 0)
# Out:
#                     0
# pess        -7.448311
# horri       -6.333779
# ruim        -5.909700
# frac        -5.862799
# decepcion   -5.738551
# dinh        -5.362749
# insatisfeit -5.299569
# receb       -5.091088
# devoluca    -4.964806
# fragil      -4.603359

# %%
pesos.nlargest(50, 0)
# Out:
#                    0
# otim       14.925728
# excel      14.384492
# bom        10.057124
# perfeit     9.367302
# ador        9.169407
# ame         7.164503
# satisfeit   7.032553
# lind        6.923753
# maravilh    6.695739
# rap         6.217399
# unic        5.543919
# parab       5.371085
# boa         4.919509
# facil       4.892200
# bem         4.853752
# sup         4.804329
# recom       4.775548
# surpreend   4.676950
# top         4.535707
# gost        4.472514
# amou        4.260134
# ant         4.227755
# exat        4.181428
# expect      4.112216
# feliz       3.997981
# rapid       3.972472
# bast        3.745396
# facilit     3.713578
# show        3.581711
# efici       3.514501
# silenci     3.492102
# sensac      3.433594
# super       3.426895
# util        3.408963
# obrig       3.393838
# ideal       3.383153
# incri       3.281100
# necess      3.260809
# praz        3.236858
# acord       3.176202
# conform     3.137964
# conhec      3.114278
# tud         3.100378
# exel        3.000276
# bonit       2.972667
# sempr       2.942059
# amo         2.939692
# aprov       2.927238
# pen         2.915181
# tranquil    2.801180
